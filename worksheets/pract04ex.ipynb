# %%
import numpy as np
import pandas as pd

# %%
# read csv & cast to DataFrame
# look at first 20 elements to get an understanding of the dataset
bank = pd.read_csv("datasets/bank.csv")
bank.iloc[:20]
# Out:
#     age            job  marital  education default  balance housing loan  \
# 0    30     unemployed  married    primary      no     1787      no   no
# 1    33       services  married  secondary      no     4789     yes  yes
# 2    35     management   single   tertiary      no     1350     yes   no
# 3    30     management  married   tertiary      no     1476     yes  yes
# 4    59    blue-collar  married  secondary      no        0     yes   no
# 5    35     management   single   tertiary      no      747      no   no
# 6    36  self-employed  married   tertiary      no      307     yes   no
# 7    39     technician  married  secondary      no      147     yes   no
# 8    41   entrepreneur  married   tertiary      no      221     yes   no
# 9    43       services  married    primary      no      -88     yes  yes
# 10   39       services  married  secondary      no     9374     yes   no
# 11   43         admin.  married  secondary      no      264     yes   no
# ...

# %%
print(f"Number of attributes: {len(bank.keys())}")
# Out:
# Number of attributes: 17

# %%
print("Value counts of loan attribute")
print(bank["loan"].value_counts(), end="\n\n")
print("Value counts of contact attribute")
print(bank["contact"].value_counts())
# Out:
# Value counts of loan attribute
# no     3830
# yes     691
# Name: loan, dtype: int64
#
# Value counts of contact attribute
# cellular     2896
# telephone     301
# Name: contact, dtype: int64

# %% [markdown]
# # Characteristics of the Dataset
# - Day is integer
# - Martial is categorical
# - poutcome contains a lot of NaN

# %%
# number of NaNs in the dataset
unique = bank.isnull()
print(unique.nunique())
print(unique.nunique().count())
# Out:
# age          1
# job          2
# marital      1
# education    2
# default      1
# balance      1
# housing      1
# loan         1
# contact      2
# day          1
# month        1
# duration     1
# campaign     1
# pdays        1
# previous     1
# poutcome     2
# y            1
# dtype: int64
# 17

# %%
# replace all the NaNs in contact attribute with "unknown"
bank["contact"].fillna("unknown",inplace = True)  
bank.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0      NaN  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0      NaN  no
# 4   unknown    5   may       226         1     -1         0      NaN  no

# %%
# breakdown of martial statuses in the dataset
bank["marital"].value_counts()
# Out:
# married     2797
# single      1196
# divorced     528
# Name: marital, dtype: int64
